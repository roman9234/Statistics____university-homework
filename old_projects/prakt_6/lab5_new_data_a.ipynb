def task(p):
    M_max_graph = [[],[]]
    M_min_graph = [[],[]]
    M_i_graph = [[],[]]
    M_c_graph = [[],[]]

    M_t_max_graph = [[],[]]
    M_t_min_graph = [[],[]]
    M_t_i_graph = [[],[]]
    M_t_c_graph = [[],[]]

    S_max_graph = [[],[]]
    S_min_graph = [[],[]]
    S_i_graph = [[],[]]
    S_c_graph = [[],[]]

    M_i_summ = 0.0
    S_i_list = []

    for n in [a41, a42, a43, a44, a45, a46]:
        M_summ = 0.0
        D_summ = 0.0
        for num in n:
            print(num)
            M_summ += num
            D_summ += num**2
        M = M_summ / len(n) # Мат. ожидание
        D = ((D_summ / len(n)) - M**2)*len(n)/(len(n)-1) # Дисперсия
        S = math.sqrt(D) # Среднее квадратичное отклонение
        
        # Граничные квантили
        quantiles_norm = norm.ppf(1-p/2, 0, 1) # нормального закона
        quantiles_t = t.ppf(1-p/2, len(n)-1) # распределения стьюдента
        
        # Доверительные интервалы для генерального среднего (нижние и верхние пределы для распределений)
        a_min_norm = M - norm.ppf(1-p/2, 0, 1)*S/math.sqrt(len(n))
        a_min_t = M - t.ppf(1-p/2, len(n)-1)*S/math.sqrt(len(n))
        a_max_norm = M + norm.ppf(1-p/2, 0, 1)*S/math.sqrt(len(n))
        a_max_t = M + t.ppf(1-p/2, len(n)-1)*S/math.sqrt(len(n))

        # Граничные квантили для хи-квадрат
        quantiles_hi_kv_max = chi2.ppf(1-p/2, len(n)-1)
        quantiles_hi_kv_min = chi2.ppf(p/2, len(n)-1)

        # Доверительные интеревалы для генеральной дисперсии
        S_min_2 = (S**2 * (len(n)-1))/chi2.ppf(1-p/2, len(n)-1)
        S_max_2 = (S**2 * (len(n)-1))/chi2.ppf(p/2, len(n)-1)
        S_a_min = math.sqrt(S_min_2)
        S_a_max = math.sqrt(S_max_2)

        M_min_graph[0].append(len(n))
        M_min_graph[1].append(a_min_norm)
        M_max_graph[0].append(len(n))
        M_max_graph[1].append(a_max_norm)
        M_i_graph[0].append(len(n))
        M_i_graph[1].append(M)

        M_t_min_graph[0].append(len(n))
        M_t_min_graph[1].append(a_min_t)
        M_t_max_graph[0].append(len(n))
        M_t_max_graph[1].append(a_max_t)
        M_t_i_graph[0].append(len(n))
        M_t_i_graph[1].append(M)

        S_min_graph[0].append(len(n))
        S_min_graph[1].append(S_a_min)
        S_max_graph[0].append(len(n))
        S_max_graph[1].append(S_a_max)
        S_i_graph[0].append(len(n))
        S_i_graph[1].append(S)

        M_i_summ += M
        S_i_list.append(S)


        # print("n", n) # n
        # print("M", M) # M
        # print(D) 
        # print("S", S) # S
        # print(quantiles_norm)
        # print(quantiles_t)
        # print("M max norm", a_min_norm) # M_max norm
        # print("M min t", a_min_t) # M_min t
        # print("M min nor", a_max_norm) # M_min nor,
        # print("M max t", a_max_t) # M max t
        # print(quantiles_hi_kv_max)
        # print(quantiles_hi_kv_min)
        # print(S_min_2)
        # print(S_max_2)
        # print("S_min", S_a_min) # S_min
        # print("S_max", S_a_max) # S_max
        # print()

    for i in [4, 6, 10, 12]:
        M_c_graph[0].append(i)

    for j in range(4):
        M_c_graph[1].append(M_i_summ/4)

    for i in [4, 6, 10, 12]:
        S_c_graph[0].append(i)

    Sc = math.sqrt( (3*(S_i_list[0]**2) + 5*(S_i_list[1]**2) +  9*(S_i_list[2]**2) + 11*(S_i_list[3]**2))/(4+6+10+12-4))
    # Sc = (3*(S_i_list[0]**2) + 5*(S_i_list[1]**2) +  9*(S_i_list[2]**2) + 11*(S_i_list[3]**2))/(4+6+10+12-4)

    for j in range(4):
        S_c_graph[1].append(Sc)

    plt.plot(M_max_graph[0], M_max_graph[1], label = "M max_i", color="r")
    plt.plot(M_min_graph[0], M_min_graph[1], label = "M min_i", color="r")
    plt.plot(M_i_graph[0], M_i_graph[1], label = "M_i")
    plt.plot(M_c_graph[0], M_c_graph[1], label = "M_c")

    plt.plot(M_t_max_graph[0], M_t_max_graph[1], label = "M_t max_i", color="b")
    plt.plot(M_t_min_graph[0], M_t_min_graph[1], label = "M_t min_i", color="b")
    plt.plot(M_t_i_graph[0], M_t_i_graph[1], label = "M_t_i")
    plt.plot(M_c_graph[0], M_c_graph[1], label = "M_t_c")

    for i in range(3):
        if i == 0:
            plt.plot(M_max_graph[0], M_max_graph[1], label = "M max_i", color="r")
            plt.plot(M_min_graph[0], M_min_graph[1], label = "M min_i", color="r")
            plt.plot(M_i_graph[0], M_i_graph[1], label = "M_i")
            plt.plot(M_c_graph[0], M_c_graph[1], label = "M_c")
            title = f"Доверительные интервалы для M при p={p}. Нормальный закон"
        elif i == 1:
            plt.plot(M_t_max_graph[0], M_t_max_graph[1], label = "M_t max_i",)
            plt.plot(M_t_min_graph[0], M_t_min_graph[1], label = "M_t min_i")
            plt.plot(M_t_i_graph[0], M_t_i_graph[1], label = "M_t_i")
            plt.plot(M_c_graph[0], M_c_graph[1], label = "M_t_c")
            title = f"Доверительные интервалы для M при p={p}. Распределение Стьюдента"
        else:
            plt.plot(S_max_graph[0], S_max_graph[1], label = "S max_i")
            plt.plot(S_min_graph[0], S_min_graph[1], label = "S min_i")
            plt.plot(S_i_graph[0], S_i_graph[1], label = "S_i")
            plt.plot(S_c_graph[0], S_c_graph[1], label = "S_c")
            title = f"Доверительные интервалы для S при p={p}"

        plt.legend(loc='center left', bbox_to_anchor=(-0.32, 0.87))
        plt.title(title)
        plt.show()


task(0.1)
# Out:
# [9.51753276604638, 12.510241351336827, 10.086062784997202, 8.015084567796615, 9.677739045321982]
# 9.51753276604638
# 12.510241351336827
# 10.086062784997202
# 8.015084567796615
# 9.677739045321982
# 8.805717354422576
# 8.98836261463424
# 10.522221218659135
# 10.357620014602952
# 8.982624828896675
# 9.522677265930275
# 8.773701900182628
# 7.366517588614766
# 8.533325288535735
# 8.322277016984023
# 10.078141385062526
# 11.299146383332827
# 6.118682609139538
# 11.63256682965297
# 11.181311679100476
# 8.2883114881591
# 8.72635413143475
# 7.9878343392263815
# 8.228377346285141
# 7.028057017927452
# 8.609604711148087
# 6.429600254963933
# 13.048380509758347
# 12.117416940467047
# 6.526533579471206
# 7.683567293535892
# 9.675869280092629
# 5.708958840016191
# 10.911525267646518
# 9.750783743377305
# 9.440333539860813
# 9.088467649314628
# 10.089742245748852
# 11.659086399776372
# 9.571416804289246
# 13.996352555143766
# 12.15492642102203
# 8.87261986035006
# 9.053864731733437
# ...
